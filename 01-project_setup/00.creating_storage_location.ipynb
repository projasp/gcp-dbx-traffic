# %%
# %sql
create external location if not exists landing_dev
url 'gs://bkt-dev-1811/landing'
with (storage credential `bkt-dev-creds`)

# %%
# %sql
create external location if not exists checkpoints_dev
url 'gs://bkt-dev-1811/checkpoints'
with (storage credential `bkt-dev-creds`)

# %%
# %sql
create external location if not exists bronze_dev
url 'gs://bkt-dev-1811/medallion/bronze'
with (storage credential `bkt-dev-creds`)

# %%
# %sql
create external location if not exists silver_dev
url 'gs://bkt-dev-1811/medallion/silver'
with (storage credential `bkt-dev-creds`)

# %%
# %sql
create external location if not exists gold_dev
url 'gs://bkt-dev-1811/medallion/gold'
with (storage credential `bkt-dev-creds`)

# %%
# %fs ls 'gs://bkt-dev-1811/landing/'

# %%
display(dbutils.fs.ls('gs://bkt-dev-1811/landing/'))
